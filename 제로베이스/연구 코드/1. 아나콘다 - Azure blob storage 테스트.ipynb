# %% [markdown]
# ### 메모리 지우는 방법

# %%
# import gc
# del 변수이름
# gc.collect()

# %%
! python --version
# Out:
# Python 3.7.2

# %%
from azure.storage.blob import BlobServiceClient
import json
import os, sys
import pandas as pd
import numpy as np

# %%
account_name = 'ulsanbuk01'
conn_str = 'DefaultEndpointsProtocol=https;AccountName=seodaemun01;AccountKey=LpAXUpqtWPzGqBq+NS7rgTNwK2SCXSya1fBiXigsywsYmX7s8w5ZKF/dcsU1p9ZDQTpZ4LbNWzq8A1VKStM+1Q==;EndpointSuffix=core.windows.net'
container = 'dmsbi'
service = 'vms'
target = 'vms_status'
target_blob = 'vms/2021/08/26/05' # 실제 파일 크기 1.36MB

# %%
blob_service_client = BlobServiceClient.from_connection_string(conn_str)

# %%
container_client = blob_service_client.get_container_client(container)

# %%
blob_client = container_client.get_blob_client(target_blob)

# %%
blob_client.exists()
# Out:
# False

# %%
stream = blob_client.download_blob()
# Out:
# ---------------------------------------------------------------------------
# ResourceNotFoundError                     Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\azure\storage\blob\_download.py in _initial_request(self)
#     385             try:
# --> 386                 location_mode, response = self._clients.blob.download(
#     387                     range=range_header,
#
# ~\anaconda3\lib\site-packages\azure\storage\blob\_generated\operations\_blob_operations.py in download(self, snapshot, version_id, timeout, range, range_get_content_md5, range_get_content_crc64, request_id_parameter, lease_access_conditions, cpk_info, modified_access_conditions, **kwargs)
#     182         if response.status_code not in [200, 206]:
# --> 183             map_error(status_code=response.status_code, response=response, error_map=error_map)
#     184             error = self._deserialize(_models.StorageError, response)
#
# ~\anaconda3\lib\site-packages\azure\core\exceptions.py in map_error(status_code, response, error_map)
#     101     error = error_type(response=response)
# --> 102     raise error
#     103
#
# ResourceNotFoundError: Operation returned an invalid status 'The specified blob does not exist.'
#
# During handling of the above exception, another exception occurred:
#
# ResourceNotFoundError                     Traceback (most recent call last)
# <ipython-input-15-69f5472b8548> in <module>
# ----> 1 stream = blob_client.download_blob()
#
# ~\anaconda3\lib\site-packages\azure\core\tracing\decorator.py in wrapper_use_tracer(*args, **kwargs)
#      81             span_impl_type = settings.tracing_implementation()
#      82             if span_impl_type is None:
# ---> 83                 return func(*args, **kwargs)
#      84
#      85             # Merge span is parameter is set, but only if no explicit parent are passed
#
# ~\anaconda3\lib\site-packages\azure\storage\blob\_blob_client.py in download_blob(self, offset, length, **kwargs)
#     826             length=length,
#     827             **kwargs)
# --> 828         return StorageStreamDownloader(**options)
#     829
#     830     def _quick_query_options(self, query_expression,
#
# ~\anaconda3\lib\site-packages\azure\storage\blob\_download.py in __init__(self, clients, config, start_range, end_range, validate_content, encryption_options, max_concurrency, name, container, encoding, **kwargs)
#     347         )
#     348
# --> 349         self._response = self._initial_request()
#     350         self.properties = self._response.properties
#     351         self.properties.name = self.name
#
# ~\anaconda3\lib\site-packages\azure\storage\blob\_download.py in _initial_request(self)
#     427                     self._file_size = 0
#     428                 else:
# --> 429                     process_storage_error(error)
#     430
#     431             try:
#
# ~\anaconda3\lib\site-packages\azure\storage\blob\_shared\response_handlers.py in process_storage_error(storage_error)
#     148     error.error_code = error_code
#     149     error.additional_info = additional_data
# --> 150     error.raise_with_traceback()
#     151
#     152
#
# ~\anaconda3\lib\site-packages\azure\core\exceptions.py in raise_with_traceback(self)
#     242     def raise_with_traceback(self):
#     243         try:
# --> 244             raise super(AzureError, self).with_traceback(self.exc_traceback)
#     245         except AttributeError:
#     246             self.__traceback__ = self.exc_traceback
#
# ~\anaconda3\lib\site-packages\azure\storage\blob\_download.py in _initial_request(self)
#     384         while retry_active:
#     385             try:
# --> 386                 location_mode, response = self._clients.blob.download(
#     387                     range=range_header,
#     388                     range_get_content_md5=range_validation,
#
# ~\anaconda3\lib\site-packages\azure\storage\blob\_generated\operations\_blob_operations.py in download(self, snapshot, version_id, timeout, range, range_get_content_md5, range_get_content_crc64, request_id_parameter, lease_access_conditions, cpk_info, modified_access_conditions, **kwargs)
#     181
#     182         if response.status_code not in [200, 206]:
# --> 183             map_error(status_code=response.status_code, response=response, error_map=error_map)
#     184             error = self._deserialize(_models.StorageError, response)
#     185             raise HttpResponseError(response=response, model=error)
#
# ~\anaconda3\lib\site-packages\azure\core\exceptions.py in map_error(status_code, response, error_map)
#     100         return
#     101     error = error_type(response=response)
# --> 102     raise error
#     103
#     104
#
# ResourceNotFoundError: The specified blob does not exist.
# RequestId:e1de8aba-201e-004d-14bb-9da746000000
# Time:2021-08-30T16:24:25.2005320Z
# ErrorCode:BlobNotFound
# Error:None

# %%
data = stream.readall()

# %%
# data

# %%
print('데이터 타입 :', type(data))
print('데이터 길이 :', len(data))
print('데이터 메모리 용량 : {0}MB'.format(round(sys.getsizeof(data)/1024/1024, 2) ))
# Out:
# 데이터 타입 : <class 'bytes'>
# 데이터 길이 : 75368158
# 데이터 메모리 용량 : 71.88MB

# %%
data_str = data.decode('utf-8')
print('데이터 타입 :', type(data_str))
print('데이터 길이 :', len(data_str))
print('데이터 메모리 용량 : {0}MB'.format(round(sys.getsizeof(data_str)/1024/1024, 2) ))
# Out:
# 데이터 타입 : <class 'str'>
# 데이터 길이 : 75368158
# 데이터 메모리 용량 : 71.88MB

# %%
def getSize(array):
    return sys.getsizeof(array) + len(array) * sys.getsizeof(array[0])

data_pro = data_str.split('\n')
print('데이터 타입 :', type(data_pro))
print('데이터 길이 :', len(data_pro))
print('데이터 메모리 용량 : {0}MB'.format(round(getSize(data_pro)/1024/1024, 2) ))
# Out:
# 데이터 타입 : <class 'list'>
# 데이터 길이 : 12279
# 데이터 메모리 용량 : 29.93MB

# %% [markdown]
# - 데이터 타입이 바이트인 상태에서 모두 합친 후 문자열 변환 및 SPLIT 하여 json_normalize 실행
# - 각 소스 실행 후 gc.collect() 처리하여 메모리 사용량 비교할 것

# %%
res = data + data
res_ls = res.decode('utf-8').split('\n')[:-1]
res_json_ls = [ json.loads(item) for item in res_ls ]
df = pd.json_normalize(res_json_ls)
df
# Out:
#                 collectTimeUTC       site targetName targetClass dataType  \
# 0      2021-08-26 05:04:08.000  seodaemun    innodep         vms  history
# 1      2021-08-26 05:04:18.000  seodaemun    innodep         vms  history
# 2      2021-08-26 05:04:28.000  seodaemun    innodep         vms  history
# 3      2021-08-26 05:04:38.000  seodaemun    innodep         vms  history
# 4      2021-08-26 05:04:48.000  seodaemun    innodep         vms  history
# ...                        ...        ...        ...         ...      ...
# 24551  2021-08-26 06:58:16.000  seodaemun    innodep         vms  history
# 24552  2021-08-26 06:58:16.000  seodaemun    innodep         vms  history
# 24553  2021-08-26 06:58:17.000  seodaemun    innodep         vms  history
# 24554  2021-08-26 07:48:44.000  seodaemun    innodep         vms  history
# 24555  2021-08-26 07:48:54.000  seodaemun    innodep         vms  history
#
#       yearPath monthPath dayPath hourPath  data.cmd  data.cnt  data.msg  \
# 0         2021        08      26       05        26        -1         0
# 1         2021        08      26       05        26        -1         0
# 2         2021        08      26       05        26        -1         0
# 3         2021        08      26       05        26        -1         0
# 4         2021        08      26       05        26        -1         0
# ...        ...       ...     ...      ...       ...       ...       ...
# 24551     2021        08      26       05        26        -1         0
# 24552     2021        08      26       05        26        -1         0
# 24553     2021        08      26       05        26        -1         0
# 24554     2021        08      26       05        26        -1         0
# 24555     2021        08      26       05        26        -1         0
#
#                                       data.param.servers data.res  \
# 0      [{'app_type': 0, 'groups': [{'group_id': 1, 'i...     None
# 1      [{'app_type': 0, 'groups': [{'group_id': 1, 'i...     None
# 2      [{'app_type': 0, 'groups': [{'group_id': 1, 'i...     None
# 3      [{'app_type': 0, 'groups': [{'group_id': 1, 'i...     None
# 4      [{'app_type': 0, 'groups': [{'group_id': 1, 'i...     None
# ...                                                  ...      ...
# 24551  [{'app_type': 1, 'groups': [{'group_id': 1, 'i...     None
# 24552  [{'app_type': 1, 'groups': [{'group_id': 1, 'i...     None
# 24553  [{'app_type': 1, 'groups': [{'group_id': 1, 'i...     None
# 24554  [{'app_type': 1, 'groups': [{'group_id': 2, 'i...     None
# 24555  [{'app_type': 1, 'groups': [{'group_id': 2, 'i...     None
#
#                 data.time
# 0      132744276051076930
# 1      132744276150915000
# 2      132744276251148060
# 3      132744276350965700
# 4      132744276451021540
# ...                   ...
# 24551  132744344533139300
# 24552  132744344533139300
# 24553  132744344533139300
# 24554  132744374801800050
# 24555  132744374901924860
#
# [24556 rows x 15 columns]

# %%
df['data.param.servers'].explode('data.param.servers')[0].keys()
# Out:
# dict_keys(['app_type', 'groups', 'srv_addr', 'srv_name', 'srv_serial', 'status', 'type', 'vms_id'])

# %%
df_ = pd.json_normalize(df['data.param.servers'].explode('data.param.servers'), record_path = 'groups', meta=['srv_name', 'srv_serial']).explode('items').reset_index().drop(['index'], axis=1)
df_items = pd.json_normalize(df_['items'])
df_cc = pd.concat([df_, df_items], axis=1).drop('items', axis=1)
df_cc.loc[:,'item_time'] = pd.to_datetime(df_cc['item_time']/10000000 - 11644473600, unit='s').astype('datetime64[s]')
df_cc.loc[:,'item_param'] = df_cc['item_param'].apply(lambda x : 'null' if 'null' in x else list(json.loads(x).values())[0])
df_cc.loc[:,'item_value_str'] = df_cc['item_value'].apply(lambda x : np.nan if x.replace('.','').isdecimal() and x.count('.') <= 1 else x)
df_cc.loc[:,'item_value']= df_cc['item_value'].apply(lambda x : pd.to_numeric(x) if x.replace('.','').isdecimal() and x.count('.') <= 1 else np.nan)
df_cc = df_cc.rename(columns={'group_id':'groups_id'})

# %%
df_
# Out:
#         group_id                                              items  status  \
# 0              1  {'item_changed': False, 'item_id': 1, 'item_pa...  normal
# 1              1  {'item_changed': False, 'item_id': 2, 'item_pa...  normal
# 2              1  {'item_changed': False, 'item_id': 3, 'item_pa...  normal
# 3              1  {'item_changed': False, 'item_id': 4, 'item_pa...  normal
# 4              3  {'item_changed': False, 'item_id': 1, 'item_pa...  normal
# ...          ...                                                ...     ...
# 849277         2  {'item_changed': False, 'item_id': 2, 'item_pa...  normal
# 849278         2  {'item_changed': False, 'item_id': 2, 'item_pa...  normal
# 849279         2  {'item_changed': False, 'item_id': 2, 'item_pa...  normal
# 849280         2  {'item_changed': False, 'item_id': 2, 'item_pa...  normal
# 849281         2  {'item_changed': False, 'item_id': 2, 'item_pa...  normal
#
#        srv_name srv_serial
# 0       VURIXMS         11
# 1       VURIXMS         11
# 2       VURIXMS         11
# 3       VURIXMS         11
# 4       VURIXMS         11
# ...         ...        ...
# 849277  VURIX02        102
# 849278  VURIX02        102
# 849279  VURIX02        102
# 849280  VURIX02        102
# 849281  VURIX02        102
#
# [849282 rows x 5 columns]

# %%
df_cc
# Out:
#         groups_id  status srv_name srv_serial  item_changed  item_id  \
# 0               1  normal  VURIXMS         11         False        1
# 1               1  normal  VURIXMS         11         False        2
# 2               1  normal  VURIXMS         11         False        3
# 3               1  normal  VURIXMS         11         False        4
# 4               3  normal  VURIXMS         11         False        1
# ...           ...     ...      ...        ...           ...      ...
# 849277          2  normal  VURIX02        102         False        2
# 849278          2  normal  VURIX02        102         False        2
# 849279          2  normal  VURIX02        102         False        2
# 849280          2  normal  VURIX02        102         False        2
# 849281          2  normal  VURIX02        102         False        2
#
#               item_param  item_save           item_time  item_value  status  \
# 0                   null       True 2021-08-26 05:00:00         5.0  normal
# 1                   null       True 2021-08-26 05:00:00        32.0  normal
# 2                   null       True 2021-08-26 05:00:00         2.0  normal
# 3                   null       True 2021-08-26 05:00:00        27.9  normal
# 4                    c:\       True 2021-08-26 05:00:00    101868.0  normal
# ...                  ...        ...                 ...         ...     ...
# 849277        drv_huawei       True 2021-08-26 05:24:38        32.3  normal
# 849278       drv_samsung       True 2021-08-26 05:24:38       144.2  normal
# 849279         drv_truen       True 2021-08-26 05:24:38        49.7  normal
# 849280       drv_win4net       True 2021-08-26 05:24:38        15.7  normal
# 849281  recording_server       True 2021-08-26 05:24:38       155.2  normal
#
#        item_value_str
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 849277            NaN
# 849278            NaN
# 849279            NaN
# 849280            NaN
# 849281            NaN
#
# [849282 rows x 12 columns]

# %%
df_new = df_cc.groupby(['srv_name', 'srv_serial', 'groups_id', 'item_id', 'item_param'], dropna=False).agg(
        recv_count = ('srv_name', 'count'),
        item_min_time = ('item_time', 'min'),
        item_max_time = ('item_time', 'max'),
        item_value = ('item_value', 'mean'),
        item_value_str = ('item_value_str', 'first')
    ).reset_index().round(3)

# %%
df_new
# Out:
#      srv_name  srv_serial  groups_id  item_id item_param  recv_count  \
# 0     VURIX01         101          1        1       null         720
# 1     VURIX01         101          1        2       null         720
# 2     VURIX01         101          1        3       null         720
# 3     VURIX01         101          1        4       null         720
# 4     VURIX01         101          2        1  drv_dahua         720
# ...       ...         ...        ...      ...        ...         ...
# 1250  VURIXMS          11          4        3       null         722
# 1251  VURIXMS          11          4        5       null         722
# 1252  VURIXMS          11          4        8       null         722
# 1253  VURIXMS          11          4        9       null         722
# 1254  VURIXMS          11          4       10       null         722
#
#            item_min_time       item_max_time  item_value  \
# 0    2021-08-26 05:00:08 2021-08-26 05:59:58      11.506
# 1    2021-08-26 05:00:08 2021-08-26 05:59:58      14.994
# 2    2021-08-26 05:00:08 2021-08-26 05:59:58     172.599
# 3    2021-08-26 05:00:08 2021-08-26 05:59:58      26.126
# 4    2021-08-26 05:00:03 2021-08-26 05:59:53       0.000
# ...                  ...                 ...         ...
# 1250 2021-08-26 05:00:00 2021-08-26 05:59:59       1.000
# 1251 2021-08-26 05:00:00 2021-08-26 05:59:59       2.000
# 1252 2021-08-26 05:00:00 2021-08-26 05:59:59         NaN
# 1253 2021-08-26 05:00:00 2021-08-26 05:59:59         NaN
# 1254 2021-08-26 05:00:00 2021-08-26 05:59:59         NaN
#
#                    item_value_str
# 0                            None
# 1                            None
# 2                            None
# 3                            None
# 4                            None
# ...                           ...
# 1250                         None
# 1251                         None
# 1252                1.6.11.210805
# 1253  OpenSSL 1.0.2k  26 Jan 2017
# 1254                         1_67
#
# [1255 rows x 10 columns]

# %%
pk_list = ['srv_name', 'srv_serial', 'groups_id', 'item_id', 'item_param']
df_servers = pd.json_normalize(df['data.param.servers'].explode('data.param.servers')).explode('groups').reset_index()
df_groups = pd.json_normalize(df_servers['groups']).drop(['status'], axis=1)
df_items = pd.concat([df_servers, df_groups], axis=1).explode('items').drop(['groups'], axis=1).reset_index()
df_ = pd.concat([df_items, pd.json_normalize(df_items['items'])], axis=1)

df_['item_time'] = pd.to_datetime(df_['item_time']/10000000 - 11644473600, unit='s').astype('datetime64[s]')
df_['item_param'] = df_['item_param'].apply(lambda x : 'null' if 'null' in x else list(json.loads(x).values())[0])
df_['item_value_str'] = df_['item_value'].apply(lambda x : np.nan if x.replace('.','').isdecimal() and x.count('.') <= 1 else x)
df_['item_value']= df_['item_value'].apply(lambda x : pd.to_numeric(x) if x.replace('.','').isdecimal() and x.count('.') <= 1 else np.nan)
df_['groups_id'] = df_['group_id']

df_new = df_.groupby(pk_list, dropna=False).agg(
    recv_count = ('srv_name', 'count'),
    item_min_time = ('item_time', 'min'),
    item_max_time = ('item_time', 'max'),
    item_value = ('item_value', 'mean'),
    item_value_str = ('item_value_str', 'first')
).reset_index().round(3)

# %%
df_
# Out:
#         level_0  index  app_type       srv_addr srv_name  srv_serial  status  \
# 0             0      0         0      localhost  VURIXMS          11  normal
# 1             0      0         0      localhost  VURIXMS          11  normal
# 2             0      0         0      localhost  VURIXMS          11  normal
# 3             0      0         0      localhost  VURIXMS          11  normal
# 4             1      0         0      localhost  VURIXMS          11  normal
# ...         ...    ...       ...            ...      ...         ...     ...
# 849277   145229  24555         1  172.23.15.142  VURIX02         102  normal
# 849278   145229  24555         1  172.23.15.142  VURIX02         102  normal
# 849279   145229  24555         1  172.23.15.142  VURIX02         102  normal
# 849280   145229  24555         1  172.23.15.142  VURIX02         102  normal
# 849281   145229  24555         1  172.23.15.142  VURIX02         102  normal
#
#          type  vms_id  group_id  \
# 0       state  100381         1
# 1       state  100381         1
# 2       state  100381         1
# 3       state  100381         1
# 4       state  100381         3
# ...       ...     ...       ...
# 849277  state  100381         2
# 849278  state  100381         2
# 849279  state  100381         2
# 849280  state  100381         2
# 849281  state  100381         2
#
#                                                     items  item_changed  \
# 0       {'item_changed': False, 'item_id': 1, 'item_pa...         False
# 1       {'item_changed': False, 'item_id': 2, 'item_pa...         False
# 2       {'item_changed': False, 'item_id': 3, 'item_pa...         False
# 3       {'item_changed': False, 'item_id': 4, 'item_pa...         False
# 4       {'item_changed': False, 'item_id': 1, 'item_pa...         False
# ...                                                   ...           ...
# 849277  {'item_changed': False, 'item_id': 2, 'item_pa...         False
# 849278  {'item_changed': False, 'item_id': 2, 'item_pa...         False
# 849279  {'item_changed': False, 'item_id': 2, 'item_pa...         False
# 849280  {'item_changed': False, 'item_id': 2, 'item_pa...         False
# 849281  {'item_changed': False, 'item_id': 2, 'item_pa...         False
#
#         item_id        item_param  item_save           item_time  item_value  \
# 0             1              null       True 2021-08-26 05:00:00         5.0
# 1             2              null       True 2021-08-26 05:00:00        32.0
# 2             3              null       True 2021-08-26 05:00:00         2.0
# 3             4              null       True 2021-08-26 05:00:00        27.9
# 4             1               c:\       True 2021-08-26 05:00:00    101868.0
# ...         ...               ...        ...                 ...         ...
# 849277        2        drv_huawei       True 2021-08-26 05:24:38        32.3
# 849278        2       drv_samsung       True 2021-08-26 05:24:38       144.2
# 849279        2         drv_truen       True 2021-08-26 05:24:38        49.7
# 849280        2       drv_win4net       True 2021-08-26 05:24:38        15.7
# 849281        2  recording_server       True 2021-08-26 05:24:38       155.2
#
#         status item_value_str  groups_id
# 0       normal            NaN          1
# 1       normal            NaN          1
# 2       normal            NaN          1
# 3       normal            NaN          1
# 4       normal            NaN          3
# ...        ...            ...        ...
# 849277  normal            NaN          2
# 849278  normal            NaN          2
# 849279  normal            NaN          2
# 849280  normal            NaN          2
# 849281  normal            NaN          2
#
# [849282 rows x 20 columns]

# %%
df_new = df_.groupby(pk_list, dropna=False).agg(
    recv_count = ('srv_name', 'count'),
    item_min_time = ('item_time', 'min'),
    item_max_time = ('item_time', 'max'),
    item_value = ('item_value', 'mean'),
    item_value_str = ('item_value_str', 'first')
).reset_index().round(3)
mask1 = (df_new['recv_count'] <= 360)
df_new.loc[mask1,:]
# Out:
#    srv_name  srv_serial  groups_id  item_id         item_param  recv_count  \
# 37  VURIX02         102          1        1               null         292
# 38  VURIX02         102          1        2               null         292
# 39  VURIX02         102          1        3               null         292
# 40  VURIX02         102          1        4               null         292
# 41  VURIX02         102          2        1  drv_arecontvision         294
# 42  VURIX02         102          2        1     drv_commonrtsp         294
# 43  VURIX02         102          2        1         drv_doowon         294
# 44  VURIX02         102          2        1      drv_hikvision         294
# 45  VURIX02         102          2        1         drv_huawei         294
# 46  VURIX02         102          2        1        drv_samsung         294
# 47  VURIX02         102          2        1          drv_truen         294
# 48  VURIX02         102          2        1        drv_win4net         294
# 49  VURIX02         102          2        1   recording_server         294
# 50  VURIX02         102          2        2  drv_arecontvision         294
# 51  VURIX02         102          2        2     drv_commonrtsp         294
# 52  VURIX02         102          2        2         drv_doowon         294
# 53  VURIX02         102          2        2      drv_hikvision         294
# 54  VURIX02         102          2        2         drv_huawei         294
# 55  VURIX02         102          2        2        drv_samsung         294
# 56  VURIX02         102          2        2          drv_truen         294
# 57  VURIX02         102          2        2        drv_win4net         294
# 58  VURIX02         102          2        2   recording_server         294
# 59  VURIX02         102          3        1         E:\vfsdata         292
# 60  VURIX02         102          3        1         F:\vfsdata         292
# 61  VURIX02         102          3        1                c:\         292
# 62  VURIX02         102          3        2         E:\vfsdata         292
# 63  VURIX02         102          3        2         F:\vfsdata         292
# 64  VURIX02         102          3        2                c:\         292
# 65  VURIX02         102          3        3         E:\vfsdata         292
# 66  VURIX02         102          3        3         F:\vfsdata         292
# 67  VURIX02         102          3        3                c:\         292
# 68  VURIX02         102          4        2               null         292
# 69  VURIX02         102          4        4               null         292
# 70  VURIX02         102          4        5               null         292
# 71  VURIX02         102          4        8               null         292
# 72  VURIX02         102          4        9               null         292
# 73  VURIX02         102          4       10               null         292
# 74  VURIX02         102          7        1               null         292
# 75  VURIX02         102          7        2               null         292
# 76  VURIX02         102          7        3               null         292
# 77  VURIX02         102          7        4               null         292
# 78  VURIX02         102          7        6               null         292
# 79  VURIX02         102          7        7               null         292
# 80  VURIX02         102          8        3               null         292
# 81  VURIX02         102          8        5               null         292
#
#          item_min_time       item_max_time    item_value  \
# 37 2021-08-26 05:00:05 2021-08-26 05:24:28  1.577400e+01
# 38 2021-08-26 05:00:05 2021-08-26 05:24:28  1.463700e+01
# 39 2021-08-26 05:00:05 2021-08-26 05:24:28  1.532970e+02
# 40 2021-08-26 05:00:05 2021-08-26 05:24:28  1.106300e+01
# 41 2021-08-26 05:00:00 2021-08-26 05:24:38  0.000000e+00
# 42 2021-08-26 05:00:00 2021-08-26 05:24:38  0.000000e+00
# 43 2021-08-26 05:00:00 2021-08-26 05:24:38  0.000000e+00
# 44 2021-08-26 05:00:00 2021-08-26 05:24:38  0.000000e+00
# 45 2021-08-26 05:00:00 2021-08-26 05:24:38  0.000000e+00
# 46 2021-08-26 05:00:00 2021-08-26 05:24:38  0.000000e+00
# 47 2021-08-26 05:00:00 2021-08-26 05:24:38  0.000000e+00
# 48 2021-08-26 05:00:00 2021-08-26 05:24:38  0.000000e+00
# 49 2021-08-26 05:00:00 2021-08-26 05:24:38  4.521000e+00
# 50 2021-08-26 05:00:00 2021-08-26 05:24:38  3.711900e+01
# 51 2021-08-26 05:00:00 2021-08-26 05:24:38  1.810700e+01
# 52 2021-08-26 05:00:00 2021-08-26 05:24:38  2.639900e+01
# 53 2021-08-26 05:00:00 2021-08-26 05:24:38  2.037800e+01
# 54 2021-08-26 05:00:00 2021-08-26 05:24:38  3.249400e+01
# 55 2021-08-26 05:00:00 2021-08-26 05:24:38  1.441760e+02
# 56 2021-08-26 05:00:00 2021-08-26 05:24:38  4.960400e+01
# 57 2021-08-26 05:00:00 2021-08-26 05:24:38  1.574100e+01
# 58 2021-08-26 05:00:00 2021-08-26 05:24:38  1.586350e+02
# 59 2021-08-26 05:00:05 2021-08-26 05:24:28  3.617574e+07
# 60 2021-08-26 05:00:05 2021-08-26 05:24:28  3.617574e+07
# 61 2021-08-26 05:00:05 2021-08-26 05:24:28  2.044470e+05
# 62 2021-08-26 05:00:05 2021-08-26 05:24:28  9.594514e+06
# 63 2021-08-26 05:00:05 2021-08-26 05:24:28  3.426644e+07
# 64 2021-08-26 05:00:05 2021-08-26 05:24:28  1.132544e+05
# 65 2021-08-26 05:00:05 2021-08-26 05:24:28  2.658123e+07
# 66 2021-08-26 05:00:05 2021-08-26 05:24:28  1.909296e+06
# 67 2021-08-26 05:00:05 2021-08-26 05:24:28  9.119257e+04
# 68 2021-08-26 05:00:05 2021-08-26 05:24:28  2.000000e+00
# 69 2021-08-26 05:00:05 2021-08-26 05:24:28  2.000000e+00
# 70 2021-08-26 05:00:05 2021-08-26 05:24:28  2.000000e+00
# 71 2021-08-26 05:00:05 2021-08-26 05:24:28           NaN
# 72 2021-08-26 05:00:05 2021-08-26 05:24:28           NaN
# 73 2021-08-26 05:00:05 2021-08-26 05:24:28           NaN
# 74 2021-08-26 05:00:05 2021-08-26 05:24:28  9.900000e+01
# 75 2021-08-26 05:00:05 2021-08-26 05:24:28  9.900000e+01
# 76 2021-08-26 05:00:05 2021-08-26 05:24:28  1.000000e+02
# 77 2021-08-26 05:00:05 2021-08-26 05:24:28  9.597300e+01
# 78 2021-08-26 05:00:05 2021-08-26 05:24:28  0.000000e+00
# 79 2021-08-26 05:00:05 2021-08-26 05:24:28  0.000000e+00
# 80 2021-08-26 05:00:05 2021-08-26 05:24:28  1.837880e+02
# 81 2021-08-26 05:00:05 2021-08-26 05:24:28  1.826430e+02
#
#                  item_value_str
# 37                         None
# 38                         None
# 39                         None
# 40                         None
# 41                         None
# 42                         None
# 43                         None
# 44                         None
# 45                         None
# 46                         None
# 47                         None
# 48                         None
# 49                         None
# 50                         None
# 51                         None
# 52                         None
# 53                         None
# 54                         None
# 55                         None
# 56                         None
# 57                         None
# 58                         None
# 59                         None
# 60                         None
# 61                         None
# 62                         None
# 63                         None
# 64                         None
# 65                         None
# 66                         None
# 67                         None
# 68                         None
# 69                         None
# 70                         None
# 71                1.6.11.210805
# 72  OpenSSL 1.0.2k  26 Jan 2017
# 73                         1_67
# 74                         None
# 75                         None
# 76                         None
# 77                         None
# 78                         None
# 79                         None
# 80                         None
# 81                         None

# %%
import psutil

# %%
# 사용중인 CPU 사용량
psutil.cpu_percent()
# Out:
# 20.0

# %%
# 사용중인 메모리 리소스 정보
psutil.virtual_memory()
# Out:
# svmem(total=34195357696, available=6791319552, percent=80.1, used=27404038144, free=6791319552)

# %%
# 사용중인 리소스 딕셔너리 타입 
dict(psutil.virtual_memory()._asdict())
# Out:
# {'total': 34195357696,
#  'available': 6791319552,
#  'percent': 80.1,
#  'used': 27404038144,
#  'free': 6791319552}

# %%
# 사용중인 리소스 딕셔너리 타입 
dict(psutil.virtual_memory()._asdict())['used']/1024/1024/1024
# Out:
# 25.52224349975586

# %%
# 사용중인 메모리 사용량 %
psutil.virtual_memory().percent
# Out:
# 80.1

# %%
# 사용중인 메모리 사용 가능 %
psutil.virtual_memory().available * 100 / psutil.virtual_memory().total
# Out:
# 19.8687401149623
